# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('border_surveillance_dataset.csv')
df
# Out:
#       object   time zone  speed    risk
# 0     Animal    Day   Z2   2.92     Low
# 1      Human    Day   Z1   1.20     Low
# 2      Human    Day   Z2   2.29  Medium
# 3      Human  Night   Z1   0.86     Low
# 4     Animal    Day   Z1   2.41     Low
# ..       ...    ...  ...    ...     ...
# 995    Human    Day   Z3   1.06     Low
# 996   Animal    Day   Z3   2.03  Medium
# 997    Human  Night   Z1   2.60     Low
# 998  Vehicle    Day   Z2   4.03  Medium
# 999   Animal    Day   Z3   1.95  Medium
#
# [1000 rows x 5 columns]

# %%
df.describe(),df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   object  1000 non-null   object
#  1   time    1000 non-null   object
#  2   zone    1000 non-null   object
#  3   speed   1000 non-null   float64
#  4   risk    1000 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 39.2+ KB
# (             speed
#  count  1000.000000
#  mean      2.712820
#  std       1.680315
#  min       0.500000
#  25%       1.505000
#  50%       2.410000
#  75%       3.300000
#  max       7.990000,
#  None)

# %%
df['object'].value_counts()
# Out:
# object
# Human      465
# Animal     306
# Vehicle    229
# Name: count, dtype: int64

# %%
df['risk'].value_counts()
# Out:
# risk
# Low       573
# Medium    321
# High      106
# Name: count, dtype: int64

# %% [markdown]
# # information about dataset

# %% [markdown]
# dataset = border surveillance dataset <br>
# features = object , time , speed , risk , zone<br>
# numerical features = speed<br>
# categorical features = object , time , risk , zone

# %% [markdown]
# # Speed

# %%
df['speed'].describe()
# Out:
# count    1000.000000
# mean        2.712820
# std         1.680315
# min         0.500000
# 25%         1.505000
# 50%         2.410000
# 75%         3.300000
# max         7.990000
# Name: speed, dtype: float64

# %%
sns.displot(data=df['speed'],kind='hist')
sns.displot(data=df['speed'],kind='kde')

# %%
df['speed'].skew()
# Out:
# np.float64(1.2562474598178952)

# %%
sns.catplot(data = df['speed'],kind='box')

# %%
# object , time , risk , zone

# %% [markdown]
# # object

# %%
sns.catplot(kind='count',data=df,x=df['object'])
